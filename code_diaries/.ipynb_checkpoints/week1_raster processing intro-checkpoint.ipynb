# %% [markdown]
# ## Familiarization with juypter notebook formatting aswell as basics for raster processing

# %% [markdown]
# Week 1 code diary

# %% [markdown]
# Practicing with raster data for the Tsistika, a northern Vancouver Island watershed where I will be conducting my research

# %%
import numpy as np
import matplotlib.pyplot as plt
import geopandas as gpd
import rasterio as rio
import rioxarray as rxr
from rasterio.plot import show
import cartopy.crs as ccrs
import os

# %matplotlib inline
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_31448/2099413431.py in <module>
#       3 import geopandas as gpd
#       4 import rasterio as rio
# ----> 5 import rioxarray as rxr
#       6 from rasterio.plot import show
#       7 import cartopy.crs as ccrs
#
# ModuleNotFoundError: No module named 'rioxarray'

# %% [markdown]
# Use the rasterio library for opening/querying. rio.open("filepath") will create python object.

# %%
#change directory to working drive
os.chdir(r"Y:\Tsitika\2021\DEM")

Tsit_be = rio.open(r'Bare_Earth\Tsitika_3m_Snow_Free_DTM_WGS84_z9_ellips.tif')

# %% [markdown]
# Use attributes to query the data.  Can index this to use with processing, ie. may use the bounding box for clipping purposes.  Can also view the metadata, note using "display" is a easier to read format than print. And can also take a quick look at the data with rasterios plotting function.

# %%
print(Tsit_be.bounds)
print(Tsit_be.bounds[0])
# Out:
# BoundingBox(left=682263.72, bottom=5566966.44, right=698691.72, top=5585230.44)
# 682263.72

# %%
display(Tsit_be.meta)
# Out:
# {'driver': 'GTiff',
#  'dtype': 'float32',
#  'nodata': -3.4028234663852886e+38,
#  'width': 5476,
#  'height': 6088,
#  'count': 1,
#  'crs': CRS.from_epsg(32609),
#  'transform': Affine(3.0, 0.0, 682263.72,
#         0.0, -3.0, 5585230.44)}

# %%
rio.plot.show(Tsit_be)
# Out:
# <AxesSubplot:>

# %%
Tsit_be.meta["width"]
# Out:
# 5476

# %%
left_bound_BE = Tsit_be.bounds[0]
display(left_bound_BE)
# Out:
# 682263.72

# %% [markdown]
# To assign the data in the raster to a numpy array, we use the "src.read" function on the open raster dataset

# %%
data_be = Tsit_be.read()
#assign the shape of the data to a variable
be_shape = data.shape
print(be_shape)
print("Number of pixels width: " + str(data.shape[1]))
print(type(data))
# Out:
# (1, 6088, 5476)
# Number of pixels width: 6088
# <class 'numpy.ndarray'>

# %% [markdown]
# Importing a snow-on raster, checking whether the data is the same size

# %%
#phase 1, snow on survey
Tsi_P01 = rio.open(r"Y:\Tsitika\2021\DEM\coregistered_STM_GUI\P01_TSI_slave.tif", masked=True)
print(Tsi_P01)
print("Numpy Array Shape:", lidar_dem_im.shape)")
# Out:
# <open DatasetReader name='Y:/Tsitika/2021/DEM/coregistered_STM_GUI/P01_TSI_slave.tif' mode='r'>

# %%
data_P01 = Tsi_P01.read()
P01_shape = data_P01.shape
#assign the shape of the data to variable
print(P01_shape)
print(data_P01)
# Out:
# (1, 6088, 5476)
# [[[-3.4028235e+38 -3.4028235e+38 -3.4028235e+38 ... -3.4028235e+38
#    -3.4028235e+38 -3.4028235e+38]
#   [-3.4028235e+38 -3.4028235e+38 -3.4028235e+38 ... -3.4028235e+38
#    -3.4028235e+38 -3.4028235e+38]
#   [-3.4028235e+38 -3.4028235e+38 -3.4028235e+38 ... -3.4028235e+38
#    -3.4028235e+38 -3.4028235e+38]
#   ...
#   [-3.4028235e+38 -3.4028235e+38 -3.4028235e+38 ... -3.4028235e+38
#    -3.4028235e+38 -3.4028235e+38]
#   [-3.4028235e+38 -3.4028235e+38 -3.4028235e+38 ... -3.4028235e+38
#    -3.4028235e+38 -3.4028235e+38]
#   [-3.4028235e+38 -3.4028235e+38 -3.4028235e+38 ... -3.4028235e+38
#    -3.4028235e+38 -3.4028235e+38]]]

# %%
#check if the arrays are the same. 
be_shape == P01_shape
# Out:
# True

# %%
Tsit_be.bounds == Tsit_P01.bounds
Tsit_be.transform == Tsit_P01.transform
# Out:
# True

# %%
P01_sd = data_P01 - data_be

# %%
# flatten the data to a 1D array
P01_ravel = np.ravel(data_P01)
print(P01_ravel)

data_ma = np.ma.masked_less(P01_ravel,0)
plt.imshow(P01_ravel)
# Out:
# [-3.4028235e+38 -3.4028235e+38 -3.4028235e+38 ... -3.4028235e+38
#  -3.4028235e+38 -3.4028235e+38]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_31448/178210954.py in <module>
#       4
#       5 data_ma = np.ma.masked_less(P01_ravel,0)
# ----> 6 plt.imshow(P01_ravel)
#       7
#       8
#
# ~\anaconda3\envs\geog650\lib\site-packages\matplotlib\_api\deprecation.py in wrapper(*args, **kwargs)
#     454                 "parameter will become keyword-only %(removal)s.",
#     455                 name=name, obj_type=f"parameter of {func.__name__}()")
# --> 456         return func(*args, **kwargs)
#     457
#     458     # Don't modify *func*'s signature, as boilerplate.py needs it.
#
# ~\anaconda3\envs\geog650\lib\site-packages\matplotlib\pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, interpolation_stage, filternorm, filterrad, resample, url, data, **kwargs)
#    2638         interpolation_stage=None, filternorm=True, filterrad=4.0,
#    2639         resample=None, url=None, data=None, **kwargs):
# -> 2640     __ret = gca().imshow(
#    2641         X, cmap=cmap, norm=norm, aspect=aspect,
#    2642         interpolation=interpolation, alpha=alpha, vmin=vmin,
#
# ~\anaconda3\envs\geog650\lib\site-packages\matplotlib\_api\deprecation.py in wrapper(*args, **kwargs)
#     454                 "parameter will become keyword-only %(removal)s.",
#     455                 name=name, obj_type=f"parameter of {func.__name__}()")
# --> 456         return func(*args, **kwargs)
#     457
#     458     # Don't modify *func*'s signature, as boilerplate.py needs it.
#
# ~\anaconda3\envs\geog650\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1410     def inner(ax, *args, data=None, **kwargs):
#    1411         if data is None:
# -> 1412             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1413
#    1414         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~\anaconda3\envs\geog650\lib\site-packages\matplotlib\axes\_axes.py in imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, interpolation_stage, filternorm, filterrad, resample, url, **kwargs)
#    5486                               **kwargs)
#    5487
# -> 5488         im.set_data(X)
#    5489         im.set_alpha(alpha)
#    5490         if im.get_clip_path() is None:
#
# ~\anaconda3\envs\geog650\lib\site-packages\matplotlib\image.py in set_data(self, A)
#     713         if not (self._A.ndim == 2
#     714                 or self._A.ndim == 3 and self._A.shape[-1] in [3, 4]):
# --> 715             raise TypeError("Invalid shape {} for image data"
#     716                             .format(self._A.shape))
#     717
#
# TypeError: Invalid shape (33337888,) for image data

# %%
# find where elevation is less than zero
a = P01sd_ravel<0
#histogram of the valid data:
plt.hist(P01sd_ravel[~a], 8)
plt.xlabel('Snow depth (m)')
plt.ylabel('Count')

ax = plt.axes(projection=ccrs.UTM(10))
ax.imshow(data,origin='upper',
          extent=img_extent, 
          transform=ccrs.UTM(10))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_31448/2788802234.py in <module>
#       8 ax = plt.axes(projection=ccrs.UTM(10))
#       9 ax.imshow(data,origin='upper',
# ---> 10           extent=img_extent,
#      11           transform=ccrs.UTM(10))
#
# NameError: name 'img_extent' is not defined

# %% [markdown]
# The next goal is to a) loop through the snow-on rasters and check if arrays are the same, and have the same meta data, and b)
