# %%
import os
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.ticker as ticker

# %%
#graphs for elevation vs SWE
sns.set_style("darkgrid")

#set parameters, will be added to function at later date
directory = r"H:\Englishman\ACO_20_3012\analysis\swe_tables"
parameter = "zbin"
wshed = "Englishman"
subbasin = "Arrowsmith"
file = subbasin + "_elevation.csv"
out_directory = r"H:\Englishman\ACO_20_3012\analysis\graphs"
elevation_swe_title = "SWE by Elevation - 2020 \n" + wshed + " watershed: " + subbasin
elevation_swe_output = "SWE_Elevation_" + wshed + "_" + subbasin + ".png"

os.chdir(directory)
df = pd.read_csv(file)

color_list = sns.color_palette()[:5]
print(color_list)


#set font sizes
SMALL_SIZE = 12
MEDIUM_SIZE = 14
BIGGER_SIZE = 20

plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=SMALL_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title


fig, ax = plt.subplots(figsize=(10,6))
fig.set_tight_layout(True)
#plt.subplots_adjust(top=.9,bottom=-.9)

p01 = df[df["phase"]==1]
p02 = df[df["phase"]==2]
p03 = df[df["phase"]==3]
p04 = df[df["phase"]==4]
p05 = df[df["phase"]==5]

p1 = ax.plot(p01["zbin"], p01["SWE_mm"], "-o", color=color_list[0])
p2 = ax.plot(p02["zbin"], p02["SWE_mm"], "-o", color=color_list[1])
p3 = ax.plot(p03["zbin"], p03["SWE_mm"], "-o", color=color_list[2])
p4 = ax.plot(p04["zbin"], p04["SWE_mm"], "-o", color=color_list[3])
p5 = ax.plot(p05["zbin"], p05["SWE_mm"], "-o", color=color_list[4])



ax.set_xlabel('Elevation [m, ASL]')
tick_spacing = 100
ax.xaxis.set_major_locator(ticker.MultipleLocator(tick_spacing))

ax.yaxis.set_ticks(np.arange(0, 1700, 200))
ax.set_ylabel('SWE [mm]')
#ax.legend([p1,p2,p3,p4,p5], labels=["P01", "P02", "P03", "P04", "P05"], loc="upper left", fontsize = "medium")
ax.legend([p1,p2,p3,p4,p5], labels=["P01: March 3 2020", "P02: April 6 2020", "P03: May 7 2020", "P04: May 27 2020", "P05: June 18 2020"], loc="upper left", fontsize = "medium")
ax.set_title(elevation_swe_title, fontsize = 20)


os.chdir(out_directory)
plt.savefig(elevation_swe_output)
plt.show()
# Out:
# [(0.12156862745098039, 0.4666666666666667, 0.7058823529411765), (1.0, 0.4980392156862745, 0.054901960784313725), (0.17254901960784313, 0.6274509803921569, 0.17254901960784313), (0.8392156862745098, 0.15294117647058825, 0.1568627450980392), (0.5803921568627451, 0.403921568627451, 0.7411764705882353)]
# C:\Users\BISHOPA\AppData\Local\Temp\ipykernel_17224\4001115934.py:60: UserWarning: You have mixed positional and keyword arguments, some input may be discarded.
#   ax.legend([p1,p2,p3,p4,p5], labels=["P01: March 3 2020", "P02: April 6 2020", "P03: May 7 2020", "P04: May 27 2020", "P05: June 18 2020"], loc="upper left", fontsize = "medium")

# %%
#graphs for elevation vs water volume
sns.set_style("darkgrid")

#set parameters, will be added to function at later date
directory = r"H:\Englishman\ACO_20_3012\analysis\swe_tables"
parameter = "zbin"
wshed = "Englishman"
subbasin = "Cokely"
file = subbasin + "_elevation.csv"
out_directory = r"H:\Englishman\ACO_20_3012\analysis\graphs"
elevation_watervol_title = "Water Volume by Elevation - 2020 \n" + wshed + " watershed: " + subbasin
elevation_watervol_output = "WaterVol_Elevation_" + wshed + "_" + subbasin + ".png"

os.chdir(directory)
df = pd.read_csv(file)
print(df)

color_list = sns.color_palette()[:5]
print(color_list)


#set font sizes
SMALL_SIZE = 12
MEDIUM_SIZE = 14
BIGGER_SIZE = 20

plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=SMALL_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title


fig, ax = plt.subplots(figsize=(10,6))
fig.set_tight_layout(True)
#plt.subplots_adjust(top=.9,bottom=-.9)

p01 = df[df["phase"]==1]
p02 = df[df["phase"]==2]
p03 = df[df["phase"]==3]
p04 = df[df["phase"]==4]
p05 = df[df["phase"]==5]

p1 = ax.plot(p01["zbin"], p01["water_volume"], "-o", color=color_list[0])
p2 = ax.plot(p02["zbin"], p02["water_volume"], "-o", color=color_list[1])
p3 = ax.plot(p03["zbin"], p03["water_volume"], "-o", color=color_list[2])
p4 = ax.plot(p04["zbin"], p04["water_volume"], "-o", color=color_list[3])
p5 = ax.plot(p05["zbin"], p05["water_volume"], "-o", color=color_list[4])



ax.set_xlabel('Elevation [m, ASL]')
tick_spacing = 100
ax.xaxis.set_major_locator(ticker.MultipleLocator(tick_spacing))

ax.yaxis.set_ticks(np.arange(0, 1800000, 200000))
ax.set_yticklabels(["0","200,000","400,000","600,000", "800,000", "1,000,000", "1,200,000", "1,400,000", "1,600,000"])
ax.set_ylabel('Water Storage [$m^{3}$]')
ax.legend([p1,p2,p3,p4,p5], labels=["P01: March 3 2020", "P02: April 6 2020", "P03: May 7 2020", "P04: May 27 2020", "P05: June 18 2020"], loc="upper left", fontsize = "medium")
ax.set_title(elevation_watervol_title, fontsize = 20)


os.chdir(out_directory)
plt.savefig(elevation_watervol_output)
plt.show()
# Out:
#     zbin   water_volume       SWE_mm  phase    date
# 0    900    1038.240839   140.683041      1   3-Mar
# 1   1000   71417.673270   168.836107      1   3-Mar
# 2   1100  198552.730700   170.820089      1   3-Mar
# 3   1200  446406.760200   338.428454      1   3-Mar
# 4   1300  536102.826800   448.560053      1   3-Mar
# 5   1400  446843.730900   599.926334      1   3-Mar
# 6   1500  271139.447300   738.053486      1   3-Mar
# 7   1600  120314.330800   796.963096      1   3-Mar
# 8   1700    1316.574760   441.951917      1   3-Mar
# 9    900     347.868130    47.136603      2   6-Apr
# 10  1000   10186.884160    24.082468      2   6-Apr
# 11  1100  128578.763900   110.619662      2   6-Apr
# 12  1200  312631.313900   237.011044      2   6-Apr
# 13  1300  406743.228000   340.324197      2   6-Apr
# 14  1400  468506.717500   629.010766      2   6-Apr
# 15  1500  317549.996500   864.385040      2   6-Apr
# 16  1600  145072.101000   960.958766      2   6-Apr
# 17  1700    1766.585966   593.013080      2   6-Apr
# 18   900      22.517367     3.051134      3   7-May
# 19  1000     500.223202     1.182561      3   7-May
# 20  1100   79447.952180    68.351144      3   7-May
# 21  1200  280637.011400   212.755627      3   7-May
# 22  1300  398279.084200   333.242203      3   7-May
# 23  1400  439228.120600   589.701718      3   7-May
# 24  1500  311756.540800   848.614999      3   7-May
# 25  1600  154971.088300  1026.529737      3   7-May
# 26  1700    1235.291443   414.666480      3   7-May
# 27   900       9.118701     0.000000      4  27-May
# 28  1000       7.730256     0.018275      4  27-May
# 29  1100     401.506894     0.345427      4  27-May
# 30  1200   52119.214860    39.512451      4  27-May
# 31  1300  121792.368400   101.904315      4  27-May
# 32  1400  169708.204700   227.847934      4  27-May
# 33  1500  151457.340000   412.273533      4  27-May
# 34  1600   88751.051970   587.887683      4  27-May
# 35  1700     470.210719   157.841799      4  27-May
# 36   900       0.000000     0.000000      5  18-Jun
# 37  1000       0.000000     0.000000      5  18-Jun
# 38  1100       0.000000     0.000000      5  18-Jun
# 39  1200    1236.044525     0.937066      5  18-Jun
# 40  1300   26748.880330    22.380929      5  18-Jun
# 41  1400   70488.063710    94.636318      5  18-Jun
# 42  1500   69823.370550   190.062282      5  18-Jun
# 43  1600   48611.128360   322.000506      5  18-Jun
# 44  1700     182.996314    61.428773      5  18-Jun
# [(0.12156862745098039, 0.4666666666666667, 0.7058823529411765), (1.0, 0.4980392156862745, 0.054901960784313725), (0.17254901960784313, 0.6274509803921569, 0.17254901960784313), (0.8392156862745098, 0.15294117647058825, 0.1568627450980392), (0.5803921568627451, 0.403921568627451, 0.7411764705882353)]
# C:\Users\BISHOPA\AppData\Local\Temp\ipykernel_17224\2591997645.py:61: UserWarning: You have mixed positional and keyword arguments, some input may be discarded.
#   ax.legend([p1,p2,p3,p4,p5], labels=["P01: March 3 2020", "P02: April 6 2020", "P03: May 7 2020", "P04: May 27 2020", "P05: June 18 2020"], loc="upper left", fontsize = "medium")
