# %%
import os
import pandas as pd
#import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from matplotlib.ticker import AutoMinorLocator

# %%
directory = r"H:\Cruickshank\2021\troubleshooting_lidar\lidar_extract\revised_lidar_12022"
os.chdir(directory)
P01 = pd.read_csv("Cruickshnak_P01_revised.csv", encoding= 'unicode_escape')
display(P01)
list1 = list(P01)
P01 = P01[['ACO_Flight_Number','Plot_ID','cardinal', 'distance','easting','northing','depth','sd_revised_CRU_P01','sd_original_lidar_no_coreg']]
# Out:
#       Shape  ACO_Flight_Number         Plot_ID         SWE   Study_Area  \
# 0   Point Z                  1         CRU_E3S   95.276429  Cruickshank
# 1   Point Z                  1         CRU_E7S   59.186872  Cruickshank
# 2   Point Z                  1         CRU_N3O  163.846585  Cruickshank
# 3   Point Z                  1         CRU_N3O  163.846585  Cruickshank
# 4   Point Z                  1         CRU_N4S   192.71823  Cruickshank
# ..      ...                ...             ...         ...          ...
# 90  Point Z                  1  CRU_snowsurvey  117.651953  Cruickshank
# 91  Point Z                  1  CRU_snowsurvey  119.095536  Cruickshank
# 92  Point Z                  1  CRU_snowsurvey   88.780308  Cruickshank
# 93  Point Z                  1  CRU_snowsurvey   92.894518  Cruickshank
# 94  Point Z                  1     CRU_WX_SR50      <Null>  Cruickshank
#
#    Survey_Start_Time cardinal    core   density  depth  ...       plot_type  \
# ...

# %%
display(P01)
P01["sd_revised_CRU_P01"]=(P01["sd_revised_CRU_P01"]*100).round(1)
P01["sd_original_lidar_no_coreg"]=(P01["sd_original_lidar_no_coreg"]*100).round(1)
display(P01)
# Out:
#     ACO_Flight_Number         Plot_ID cardinal distance     easting  \
# 0                   1         CRU_E3S   Centre   <Null>  329432.389
# 1                   1         CRU_E7S   Centre   <Null>  330730.029
# 2                   1         CRU_N3O   Centre   <Null>  328983.599
# 3                   1         CRU_N3O   Centre   <Null>  328983.599
# 4                   1         CRU_N4S   Centre   <Null>  328488.760
# ..                ...             ...      ...      ...         ...
# 90                  1  CRU_snowsurvey   <Null>   <Null>  329584.780
# 91                  1  CRU_snowsurvey   <Null>   <Null>  329584.780
# 92                  1  CRU_snowsurvey   <Null>   <Null>  329584.780
# 93                  1  CRU_snowsurvey   <Null>   <Null>  329584.780
# 94                  1     CRU_WX_SR50   <Null>   <Null>  329591.912
#
#        northing  depth  sd_revised_CRU_P01  sd_original_lidar_no_coreg
# 0   5504540.275  336.0            0.779907                    0.949951
# ...

# %%
P01.to_csv("CRU_P01_revised.csv")

# %%
P02 = pd.read_csv("CRU_P02_revised.csv", encoding= 'unicode_escape')
display(P02)
list1 = list(P02)
P02 = P02[['ACO_Flight_Number','Plot_ID','cardinal', 'distance','easting','northing','depth','sd_revised_CRU_P02_no_coreg','sd_original_lidar_P02_nocoreg']]
display(P02)
# Out:
#      OBJECTID    Shape  ACO_Flight_Number         Plot_ID         SWE  \
# 0           1  Point Z                  2         CRU_S4F   75.788068
# 1           2  Point Z                  2         CRU_S2F   73.622695
# 2           3  Point Z                  2         CRU_S5O   95.276429
# 3           4  Point Z                  2         CRU_S3F  117.651953
# 4           5  Point Z                  2         CRU_N1A   20.931943
# ..        ...      ...                ...             ...         ...
# 258       259  Point Z                  2  CRU_snowsurvey   99.607175
# 259       260  Point Z                  2  CRU_snowsurvey  112.599416
# 260       261  Point Z                  2  CRU_snowsurvey  123.426282
# 261       262  Point Z                  2  CRU_snowpillow    95.99822
# 262       263  Point Z                  2     CRU_WX_SR50      <Null>
#
#       Study_Area     Survey_Start_Time cardinal    core   density  ...  \
# ...

# %%
display(P02)
P02["sd_revised_CRU_P02_no_coreg"]=(P02["sd_revised_CRU_P02_no_coreg"]*100).round(1)
P02["sd_original_lidar_P02_nocoreg"]=(P02["sd_original_lidar_P02_nocoreg"]*100).round(1)
display(P02)
# Out:
#      ACO_Flight_Number         Plot_ID cardinal distance     easting  \
# 0                    2         CRU_S4F   Centre   <Null>  328998.829
# 1                    2         CRU_S2F   Centre   <Null>  328740.519
# 2                    2         CRU_S5O   Centre   <Null>  329405.455
# 3                    2         CRU_S3F   Centre   <Null>  328738.669
# 4                    2         CRU_N1A   Centre   <Null>  328013.670
# ..                 ...             ...      ...      ...         ...
# 258                  2  CRU_snowsurvey   <Null>   <Null>  329584.780
# 259                  2  CRU_snowsurvey   <Null>   <Null>  329584.780
# 260                  2  CRU_snowsurvey   <Null>   <Null>  329584.780
# 261                  2  CRU_snowpillow   <Null>   <Null>  329589.580
# 262                  2     CRU_WX_SR50   <Null>   <Null>  329591.912
#
#         northing  depth  sd_revised_CRU_P02_no_coreg  \
# 0    5504069.787    324                    -0.609985
# ...

# %%
P02.to_csv("CRU_P02_revised_1.csv")
